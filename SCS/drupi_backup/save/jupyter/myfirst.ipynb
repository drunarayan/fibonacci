# %%
import import_ipynb

# %%
import mymath
# Out:
# importing Jupyter notebook from mymath.ipynb
# ..
# ├── cpu_temp.txt
# ├── image.jpg
# ├── images
# │   ├── cfls
# │   │   ├── image0001.jpg
# │   │   └── image0002.jpg
# │   ├── day
# │   │   ├── image0001.jpg
# │   │   └── image0002.jpg
# │   ├── dfls
# │   │   ├── image0001.jpg
# │   │   └── image0002.jpg
# │   ├── fls
# │   │   ├── image0001.jpg
# │   │   └── image0002.jpg
# │   ├── inc
# │   │   ├── image0001.jpg
# │   │   └── image0002.jpg
# │   ├── old
# │   │   ├── image0001.jpg
# │   │   ├── image0002.jpg
# │   │   ├── image0003.jpg
# │   │   ├── image0004.jpg
# │   │   ├── image0005.jpg
# │   │   ├── image0006.jpg
# │   │   ├── image0007.jpg
# │   │   ├── image0008.jpg
# │   │   ├── image0009.jpg
# │   │   ├── image0010.jpg
# │   │   ├── image0011.jpg
# │   │   ├── image0012.jpg
# │   │   ├── image0013.jpg
# │   │   ├── image0014.jpg
# │   │   ├── image0015.jpg
# │   │   ├── image0016.jpg
# │   │   ├── image0017.jpg
# │   │   ├── image0018.jpg
# │   │   ├── image0019.jpg
# ...

# %%
print(mymath.mysquare(5))
# Out:
# 25
