# %%
def test1():
    ssp = []
    for i in range(1,5):
        ssp.append(i)
    return ssp

ssp = test1()
print(ssp)
# Out:
# [1, 2, 3, 4]

# %%
import sys
import math
import time
import picamera
import PIL
from fractions import Fraction
from collections import OrderedDict
from PIL import Image, ImageDraw, ImageFile, ImageFont
from glob import glob
import os, sys
import time
from datetime import datetime
from IPython.core.display import Image, display

# scan a column to determine top and bottom of area of lightness
def get_spectrum_y_bound(pix, x, middle_y, spectrum_threshold, spectrum_threshold_duration):
    c = 0
    spectrum_top = middle_y
    for y in range(middle_y, 0, -1):
        r, g, b = pix[x, y]
        brightness = r + g + b
        if brightness < spectrum_threshold:
            c = c + 1
            if c > spectrum_threshold_duration:
                break
        else:
            spectrum_top = y
            c = 0

    c = 0
    spectrum_bottom = middle_y
    for y in range(middle_y, middle_y * 2, 1):
        r, g, b = pix[x, y]
        brightness = r + g + b
        if brightness < spectrum_threshold:
            c = c + 1
            if c > spectrum_threshold_duration:
                break
        else:
            spectrum_bottom = y
            c = 0
    print("spectrum_top is %d spectrum bottom is %d" % (spectrum_top, spectrum_bottom))
    return spectrum_top, spectrum_bottom - 50


# find aperture on right hand side of image along middle line
def find_aperture(pic_pixels, pic_width, pic_height):
    middle_x = int(pic_width / 2)
    middle_y = int(pic_height / 2)
    aperture_brightest = 0
    aperture_x = 0
    for x in range(middle_x, pic_width, 1):
        r, g, b = pic_pixels[x, middle_y]
        brightness = r + g + b
        if brightness > aperture_brightest:
            aperture_brightest = brightness
            aperture_x = x

    aperture_threshold = aperture_brightest * 0.9
    aperture_x1 = aperture_x
    for x in range(aperture_x, middle_x, -1):
        r, g, b = pic_pixels[x, middle_y]
        brightness = r + g + b
        if brightness < aperture_threshold:
            aperture_x1 = x
            break

    aperture_x2 = aperture_x
    for x in range(aperture_x, pic_width, 1):
        r, g, b = pic_pixels[x, middle_y]
        brightness = r + g + b
        if brightness < aperture_threshold:
            aperture_x2 = x
            break

    aperture_x = (aperture_x1 + aperture_x2) / 2

    spectrum_threshold_duration = 64
    aperture_y_bounds = get_spectrum_y_bound(pic_pixels, aperture_x, middle_y, aperture_threshold, spectrum_threshold_duration)
    aperture_y = (aperture_y_bounds[0] + aperture_y_bounds[1]) / 2
    aperture_height = (aperture_y_bounds[1] - aperture_y_bounds[0]) * 1.0

    return {'x': aperture_x, 'y': aperture_y, 'h': aperture_height, 'b': aperture_brightest}


# draw aperture onto image
def draw_aperture(aperture, draw):
    fill_color = "#000"
    draw.line((aperture['x'], aperture['y'] - aperture['h'] / 2, aperture['x'], aperture['y'] + aperture['h'] / 2),
              fill=fill_color)


# draw scan line
def draw_scan_line(aperture, draw, spectrum_angle):
    fill_color = "#888"
    xd = aperture['x']
    h = aperture['h'] / 2
    y0 = math.tan(spectrum_angle) * xd + aperture['y']
    draw.line((0, y0 - h, aperture['x'], aperture['y'] - h), fill=fill_color)
    draw.line((0, y0 + h, aperture['x'], aperture['y'] + h), fill=fill_color)


# return an RGB visual representation of wavelength for chart
# Based on: http://www.efg2.com/Lab/ScienceAndEngineering/Spectra.htm
# The foregoing is based on: http://www.midnightkite.com/color.html
# thresholds = [ 380, 440, 490, 510, 580, 645, 780 ]
#                vio  blu  cyn  gre  yel  org  red
def wavelength_to_color(lambda2):
    factor = 0.0
    color = [0, 0, 0]
    thresholds = [380, 400, 450, 465, 520, 565, 780]
    for i in range(0, len(thresholds) - 1, 1):
        t1 = thresholds[i]
        t2 = thresholds[i + 1]
        if lambda2 < t1 or lambda2 >= t2:
            continue
        if i % 2 != 0:
            tmp = t1
            t1 = t2
            t2 = tmp
        if i < 5:
            color[i % 3] = (lambda2 - t2) / (t1 - t2)
        color[2 - int(i / 2)] = 1.0
        factor = 1.0
        break

    # Let the intensity fall off near the vision limits
    if 380 <= lambda2 < 420:
        factor = 0.2 + 0.8 * (lambda2 - 380) / (420 - 380)
    elif 600 <= lambda2 < 780:
        factor = 0.2 + 0.8 * (780 - lambda2) / (780 - 600)
    return int(255 * color[0] * factor), int(255 * color[1] * factor), int(255 * color[2] * factor)


def take_spectrum(name, shutter):
    try:
        os.remove("capture_lockfile")
    except OSError:
            pass
    camera = picamera.PiCamera()
    try:
        print("allowing camera to warmup")
        camera.vflip = True
        camera.hflip = True
        camera.framerate = Fraction(1, 2)
        camera.shutter_speed = shutter
        camera.iso = 100
        camera.exposure_mode = 'off'
        camera.awb_mode = 'off'
        camera.awb_gains = (1, 1)
        time.sleep(3)
        print("capturing image")
        camera.capture(name + ".jpg", resize=(1296, 972))
    finally:
        camera.close()
        print("closing camera")
        os.mknod("capture_lockfile")
    return name

def determine_shutter(name, guess_shutter, ntrials):
    print("trying with increasing shutter speeds")
    shutter_speeds = []
    shutter_speed_index = 0

    for trial in range(1,ntrials+1):
        shutter_speeds.append(guess_shutter * trial)
        try:
            os.remove("capture_lockfile")
        except OSError:
                pass
        camera = picamera.PiCamera()
        try:
            print("allowing camera to warmup")
            camera.vflip = True
            camera.hflip = True
            camera.framerate = Fraction(1, 2)
            camera.shutter_speed = shutter_speeds[shutter_speed_index]
            camera.iso = 100
            camera.exposure_mode = 'off'
            camera.awb_mode = 'off'
            camera.awb_gains = (1, 1)
            time.sleep(3)
            print("capturing image at shutter speed %d" % shutter_speeds[shutter_speed_index])
            camera.capture(name + "_" + str(trial) + ".jpg", resize=(1296, 972))
        finally:
            camera.close()
            print("closing camera")
            os.mknod("capture_lockfile")
            shutter_speed_index += 1

    return shutter_speeds

def getSize(filename):
    if os.path.isfile(filename): 
        st = os.stat(filename)
        return st.st_size
    else:
        return -1

def wait_capture(file_path):
    time_to_wait = 10
    time_counter = 0
    while not os.path.exists(file_path):
        time.sleep(1)
        time_counter += 1
        if time_counter > time_to_wait:
            break

print("done")


def draw_graph(draw, pic_pixels, aperture, spectrum_angle, wavelength_factor):
    aperture_height = aperture['h'] / 2
    step = 1
    last_graph_y = 0
    max_result = 0
    results = OrderedDict()
    for x in range(0, int(aperture['x'] * 7 / 8), step):
        wavelength = (aperture['x'] - x) * wavelength_factor
        if 1000 < wavelength or wavelength < 380:
            continue

        # general efficiency curve of 1000/mm grating
        eff = (800 - (wavelength - 250)) / 800
        if eff < 0.3:
            eff = 0.3

        # notch near yellow maybe caused by camera sensitivity
        mid = 571
        width = 14
        if (mid - width) < wavelength < (mid + width):
            d = (width - abs(wavelength - mid)) / width
            eff = eff * (1 - d * 0.12)

        # up notch near 590
        #mid = 588
        #width = 10
        #if (mid - width) < wavelength < (mid + width):
        #    d = (width - abs(wavelength - mid)) / width
        #    eff = eff * (1 + d * 0.1)

        y0 = math.tan(spectrum_angle) * (aperture['x'] - x) + aperture['y']
        amplitude = 0
        ac = 0.0
        for y in range(int(y0 - aperture_height), int(y0 + aperture_height), 1):
            r, g, b = pic_pixels[x, y]
            q = r + b + g * 2
            if y < (y0 - aperture_height + 2) or y > (y0 + aperture_height - 3):
                q = q * 0.5
            amplitude = amplitude + q
            ac = ac + 1.0
        amplitude = amplitude / ac / eff
        # amplitude=1/eff
        results[str(wavelength)] = amplitude
        if amplitude > max_result:
            max_result = amplitude
        graph_y = amplitude / 50 * aperture_height
        draw.line((x - step, y0 + aperture_height - last_graph_y, x, y0 + aperture_height - graph_y), fill="#fff")
        last_graph_y = graph_y
    draw_ticks_and_frequencies(draw, aperture, spectrum_angle, wavelength_factor)
    return results, max_result


def draw_ticks_and_frequencies(draw, aperture, spectrum_angle, wavelength_factor):
    aperture_height = aperture['h'] / 2
    for wl in range(400, 1001, 50):
        x = aperture['x'] - (wl / wavelength_factor)
        y0 = math.tan(spectrum_angle) * (aperture['x'] - x) + aperture['y']
        draw.line((x, y0 + aperture_height + 5, x, y0 + aperture_height - 5), fill="#fff")
        font = ImageFont.truetype('/usr/share/fonts/truetype/lato/Lato-Regular.ttf', 12)
        draw.text((x, y0 + aperture_height + 15), str(wl), font=font, fill="#fff")


def inform_user_of_exposure(max_result):
    exposure = max_result / (255 + 255 + 255)
    print("ideal exposure between 0.15 and 0.30")
    print("exposure=", exposure)
    if exposure < 0.15:
        print("consider increasing shutter time")
    elif exposure > 0.3:
        print("consider reducing shutter time")


def save_image_with_overlay(im, name):
    output_filename = name + "_out.jpg"
    ImageFile.MAXBLOCK = 2 ** 20
    im.save(output_filename, "JPEG", quality=80, optimize=True, progressive=True)


def normalize_results(results, max_result):
    for wavelength in results:
        results[wavelength] = results[wavelength] / max_result
    return results


def export_csv(name, normalized_results):
    csv_filename = name + ".csv"
    csv = open(csv_filename, 'w')
    csv.write("wavelength,amplitude\n")
    for wavelength in normalized_results:
        csv.write(wavelength)
        csv.write(",")
        csv.write("{:0.3f}".format(normalized_results[wavelength]))
        csv.write("\n")
    csv.close()


def export_diagram(name, normalized_results):
    antialias = 4
    w = 600 * antialias
    h2 = 300 * antialias

    h = h2 - 20 * antialias
    sd = PIL.Image.new('RGB', (w, h2), (255, 255, 255))
    draw = PIL.ImageDraw.Draw(sd)

    w1 = 380.0
    w2 = 780.0
    f1 = 1.0 / w1
    f2 = 1.0 / w2
    for x in range(0, w, 1):
        # Iterate across frequencies, not wavelengths
        lambda2 = 1.0 / (f1 - (float(x) / float(w) * (f1 - f2)))
        c = wavelength_to_color(lambda2)
        draw.line((x, 0, x, h), fill=c)

    pl = [(w, 0), (w, h)]
    for wavelength in normalized_results:
        wl = float(wavelength)
        x = int((wl - w1) / (w2 - w1) * w)
        # print wavelength,x
        pl.append((int(x), int((1 - normalized_results[wavelength]) * h)))
    pl.append((0, h))
    pl.append((0, 0))
    draw.polygon(pl, fill="#FFF")
    draw.polygon(pl)

    font = PIL.ImageFont.truetype('/usr/share/fonts/truetype/lato/Lato-Regular.ttf', 12 * antialias)
    draw.line((0, h, w, h), fill="#000", width=antialias)

    for wl in range(400, 1001, 10):
        x = int((float(wl) - w1) / (w2 - w1) * w)
        draw.line((x, h, x, h + 3 * antialias), fill="#000", width=antialias)

    for wl in range(400, 1001, 50):
        x = int((float(wl) - w1) / (w2 - w1) * w)
        draw.line((x, h, x, h + 5 * antialias), fill="#000", width=antialias)
        wls = str(wl)
        tx = draw.textsize(wls, font=font)
        draw.text((x - tx[0] / 2, h + 5 * antialias), wls, font=font, fill="#000")

    # save chart
    sd = sd.resize((int(w / antialias), int(h / antialias)), PIL.Image.ANTIALIAS)
    output_filename = name + "_chart.png"
    sd.save(output_filename, "PNG", quality=95, optimize=True, progressive=True)
# Out:
# done

# %%
# !ls
# Out:
# bds_v5.ipynb		   eve1123011034_1_chart.png  eve1123015135_2_chart.png
# bds_vBAD.ipynb		   eve1123011034_1.csv	      eve1123015135_2.csv
# capture_lockfile	   eve1123011034_1_out.jpg    eve1123015135_2_out.jpg
# eve1122235853_1_chart.png  eve1123011034_2_chart.png  eve1123015135_raw_1.jpg
# eve1122235853_1.csv	   eve1123011034_2.csv	      eve1123015135_raw_2.jpg
# eve1122235853_1_out.jpg    eve1123011034_2_out.jpg    eve1123015721_1_chart.png
# eve1122235853_2_chart.png  eve1123011034_raw_1.jpg    eve1123015721_1.csv
# eve1122235853_2.csv	   eve1123011034_raw_2.jpg    eve1123015721_1_out.jpg
# eve1122235853_2_out.jpg    eve1123013100_raw_1.jpg    eve1123015721_2_chart.png
# eve1122235853_3_chart.png  eve1123013100_raw_2.jpg    eve1123015721_2.csv
# eve1122235853_3.csv	   eve1123013320_raw_1.jpg    eve1123015721_2_out.jpg
# eve1122235853_3_out.jpg    eve1123013320_raw_2.jpg    eve1123015721_raw_1.jpg
# eve1122235853_4_chart.png  eve1123014116_1_chart.png  eve1123015721_raw_2.jpg
# eve1122235853_4.csv	   eve1123014116_1.csv	      eve1123015940_1_chart.png
# eve1122235853_4_out.jpg    eve1123014116_1_out.jpg    eve1123015940_1.csv
# eve1122235853_5_chart.png  eve1123014116_2_chart.png  eve1123015940_1_out.jpg
# eve1122235853_5.csv	   eve1123014116_2.csv	      eve1123015940_2_chart.png
# eve1122235853_5_out.jpg    eve1123014116_2_out.jpg    eve1123015940_2.csv
# eve1122235853_raw_1.jpg    eve1123014116_raw_1.jpg    eve1123015940_2_out.jpg
# eve1122235853_raw_2.jpg    eve1123014116_raw_2.jpg    eve1123015940_raw_1.jpg
# eve1122235853_raw_3.jpg    eve1123014855_1_chart.png  eve1123015940_raw_2.jpg
# eve1122235853_raw_4.jpg    eve1123014855_1.csv	      eve1123020101_1_chart.png
# eve1122235853_raw_5.jpg    eve1123014855_1_out.jpg    eve1123020101_1.csv
# eve1123010343_1_chart.png  eve1123014855_2_chart.png  eve1123020101_1_out.jpg
# eve1123010343_1.csv	   eve1123014855_2.csv	      eve1123020101_2_chart.png
# eve1123010343_1_out.jpg    eve1123014855_2_out.jpg    eve1123020101_2.csv
# eve1123010343_2_chart.png  eve1123014855_raw_1.jpg    eve1123020101_2_out.jpg
# eve1123010343_2.csv	   eve1123014855_raw_2.jpg    eve1123020101_raw_1.jpg
# eve1123010343_2_out.jpg    eve1123015135_1_chart.png  eve1123020101_raw_2.jpg
# eve1123010343_raw_1.jpg    eve1123015135_1.csv	      junk
# eve1123010343_raw_2.jpg    eve1123015135_1_out.jpg    save

# %%
# 1. Take Spectrum image
now = datetime.now()
source = 'eve'
name = source + now.strftime("%m%d%H%M%S")
raw_filename = name + "_raw"

print(raw_filename)

start = time.time()
shutter = 1000000
#take_spectrum(raw_filename,shutter)
shutter_settings = determine_shutter(raw_filename,shutter,2)
end = time.time()
print('elapsed time is:',end-start)
# Out:
# eve1123021144_raw
# trying with increasing shutter speeds
# allowing camera to warmup
# capturing image at shutter speed 1000000
# closing camera
# allowing camera to warmup
# capturing image at shutter speed 2000000
# closing camera
# elapsed time is: 34.34698534011841

# %%
wait_capture("capture_lockfile")

# %%
# !ls -ltr
# Out:
# total 6548
# drwxr-xr-x 2 pi pi   4096 Nov 22 23:13 save
# drwxr-xr-x 2 pi pi   4096 Nov 22 23:58 junk
# -rw-r--r-- 1 pi pi  27970 Nov 22 23:59 eve1122235853_raw_1.jpg
# -rw-r--r-- 1 pi pi  33735 Nov 22 23:59 eve1122235853_raw_2.jpg
# -rw-r--r-- 1 pi pi  40264 Nov 22 23:59 eve1122235853_raw_3.jpg
# -rw-r--r-- 1 pi pi  46333 Nov 22 23:59 eve1122235853_raw_4.jpg
# -rw-r--r-- 1 pi pi  51706 Nov 23 00:00 eve1122235853_raw_5.jpg
# -rw-r--r-- 1 pi pi   9756 Nov 23 00:00 eve1122235853_1_out.jpg
# -rw-r--r-- 1 pi pi     21 Nov 23 00:00 eve1122235853_1.csv
# -rw-r--r-- 1 pi pi   3314 Nov 23 00:00 eve1122235853_1_chart.png
# -rw-r--r-- 1 pi pi  10613 Nov 23 00:00 eve1122235853_2_out.jpg
# -rw-r--r-- 1 pi pi     21 Nov 23 00:00 eve1122235853_2.csv
# -rw-r--r-- 1 pi pi   3314 Nov 23 00:00 eve1122235853_2_chart.png
# -rw-r--r-- 1 pi pi  11481 Nov 23 00:00 eve1122235853_3_out.jpg
# -rw-r--r-- 1 pi pi     21 Nov 23 00:00 eve1122235853_3.csv
# -rw-r--r-- 1 pi pi   3314 Nov 23 00:00 eve1122235853_3_chart.png
# -rw-r--r-- 1 pi pi  12298 Nov 23 00:00 eve1122235853_4_out.jpg
# -rw-r--r-- 1 pi pi     21 Nov 23 00:00 eve1122235853_4.csv
# -rw-r--r-- 1 pi pi   3314 Nov 23 00:00 eve1122235853_4_chart.png
# -rw-r--r-- 1 pi pi  12976 Nov 23 00:00 eve1122235853_5_out.jpg
# -rw-r--r-- 1 pi pi     21 Nov 23 00:00 eve1122235853_5.csv
# -rw-r--r-- 1 pi pi   3314 Nov 23 00:00 eve1122235853_5_chart.png
# -rw-r--r-- 1 pi pi 173839 Nov 23 01:03 eve1123010343_raw_1.jpg
# -rw-r--r-- 1 pi pi 251728 Nov 23 01:04 eve1123010343_raw_2.jpg
# -rw-r--r-- 1 pi pi  47568 Nov 23 01:06 eve1123010343_1_out.jpg
# -rw-r--r-- 1 pi pi  11405 Nov 23 01:06 eve1123010343_1.csv
# -rw-r--r-- 1 pi pi  18878 Nov 23 01:06 eve1123010343_1_chart.png
# -rw-r--r-- 1 pi pi  58307 Nov 23 01:06 eve1123010343_2_out.jpg
# -rw-r--r-- 1 pi pi  11405 Nov 23 01:06 eve1123010343_2.csv
# -rw-r--r-- 1 pi pi  20130 Nov 23 01:06 eve1123010343_2_chart.png
# -rw-r--r-- 1 pi pi 166715 Nov 23 01:10 eve1123011034_raw_1.jpg
# -rw-r--r-- 1 pi pi 250699 Nov 23 01:11 eve1123011034_raw_2.jpg
# -rw-r--r-- 1 pi pi  42056 Nov 23 01:18 eve1123011034_1_out.jpg
# -rw-r--r-- 1 pi pi  11502 Nov 23 01:18 eve1123011034_1.csv
# -rw-r--r-- 1 pi pi  17413 Nov 23 01:18 eve1123011034_1_chart.png
# -rw-r--r-- 1 pi pi  55102 Nov 23 01:18 eve1123011034_2_out.jpg
# -rw-r--r-- 1 pi pi  11405 Nov 23 01:18 eve1123011034_2.csv
# -rw-r--r-- 1 pi pi  19422 Nov 23 01:18 eve1123011034_2_chart.png
# -rw-r--r-- 1 pi pi 171148 Nov 23 01:31 eve1123013100_raw_1.jpg
# -rw-r--r-- 1 pi pi 250794 Nov 23 01:31 eve1123013100_raw_2.jpg
# -rw-r--r-- 1 pi pi 167467 Nov 23 01:33 eve1123013320_raw_1.jpg
# -rw-r--r-- 1 pi pi 250483 Nov 23 01:33 eve1123013320_raw_2.jpg
# -rw-r--r-- 1 pi pi 169940 Nov 23 01:41 eve1123014116_raw_1.jpg
# -rw-r--r-- 1 pi pi 250180 Nov 23 01:41 eve1123014116_raw_2.jpg
# -rw-r--r-- 1 pi pi  41152 Nov 23 01:41 eve1123014116_1_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 01:41 eve1123014116_1.csv
# -rw-r--r-- 1 pi pi   6721 Nov 23 01:41 eve1123014116_1_chart.png
# -rw-r--r-- 1 pi pi  52890 Nov 23 01:41 eve1123014116_2_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 01:41 eve1123014116_2.csv
# -rw-r--r-- 1 pi pi   7833 Nov 23 01:41 eve1123014116_2_chart.png
# -rw-r--r-- 1 pi pi 160121 Nov 23 01:49 eve1123014855_raw_1.jpg
# -rw-r--r-- 1 pi pi 244920 Nov 23 01:49 eve1123014855_raw_2.jpg
# -rw-r--r-- 1 pi pi  39798 Nov 23 01:49 eve1123014855_1_out.jpg
# -rw-r--r-- 1 pi pi   9026 Nov 23 01:49 eve1123014855_1.csv
# -rw-r--r-- 1 pi pi   6587 Nov 23 01:49 eve1123014855_1_chart.png
# -rw-r--r-- 1 pi pi  51892 Nov 23 01:49 eve1123014855_2_out.jpg
# -rw-r--r-- 1 pi pi   9026 Nov 23 01:49 eve1123014855_2.csv
# -rw-r--r-- 1 pi pi   7621 Nov 23 01:49 eve1123014855_2_chart.png
# -rw-r--r-- 1 pi pi 164761 Nov 23 01:51 eve1123015135_raw_1.jpg
# -rw-r--r-- 1 pi pi 244970 Nov 23 01:52 eve1123015135_raw_2.jpg
# -rw-r--r-- 1 pi pi  40291 Nov 23 01:56 eve1123015135_1_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 01:56 eve1123015135_1.csv
# -rw-r--r-- 1 pi pi   6806 Nov 23 01:56 eve1123015135_1_chart.png
# -rw-r--r-- 1 pi pi  52217 Nov 23 01:56 eve1123015135_2_out.jpg
# -rw-r--r-- 1 pi pi   9026 Nov 23 01:56 eve1123015135_2.csv
# -rw-r--r-- 1 pi pi   7856 Nov 23 01:56 eve1123015135_2_chart.png
# -rw-r--r-- 1 pi pi 162817 Nov 23 01:57 eve1123015721_raw_1.jpg
# -rw-r--r-- 1 pi pi 244735 Nov 23 01:57 eve1123015721_raw_2.jpg
# -rw-r--r-- 1 pi pi  40738 Nov 23 01:58 eve1123015721_1_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 01:58 eve1123015721_1.csv
# -rw-r--r-- 1 pi pi   7049 Nov 23 01:58 eve1123015721_1_chart.png
# -rw-r--r-- 1 pi pi  52699 Nov 23 01:58 eve1123015721_2_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 01:58 eve1123015721_2.csv
# -rw-r--r-- 1 pi pi   8028 Nov 23 01:58 eve1123015721_2_chart.png
# -rw-r--r-- 1 pi pi 167221 Nov 23 01:59 eve1123015940_raw_1.jpg
# -rw-r--r-- 1 pi pi 244784 Nov 23 02:00 eve1123015940_raw_2.jpg
# -rw-r--r-- 1 pi pi  41305 Nov 23 02:00 eve1123015940_1_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 02:00 eve1123015940_1.csv
# -rw-r--r-- 1 pi pi   7058 Nov 23 02:00 eve1123015940_1_chart.png
# -rw-r--r-- 1 pi pi  52883 Nov 23 02:00 eve1123015940_2_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 02:00 eve1123015940_2.csv
# -rw-r--r-- 1 pi pi   7958 Nov 23 02:00 eve1123015940_2_chart.png
# -rw-r--r-- 1 pi pi 160134 Nov 23 02:01 eve1123020101_raw_1.jpg
# -rw-r--r-- 1 pi pi 294114 Nov 23 02:01 bds_vBAD.ipynb
# -rw-r--r-- 1 pi pi 245326 Nov 23 02:01 eve1123020101_raw_2.jpg
# -rw-r--r-- 1 pi pi  37409 Nov 23 02:05 eve1123020101_1_out.jpg
# -rw-r--r-- 1 pi pi  11405 Nov 23 02:05 eve1123020101_1.csv
# -rw-r--r-- 1 pi pi  16967 Nov 23 02:05 eve1123020101_1_chart.png
# -rw-r--r-- 1 pi pi  49478 Nov 23 02:05 eve1123020101_2_out.jpg
# -rw-r--r-- 1 pi pi  11405 Nov 23 02:05 eve1123020101_2.csv
# -rw-r--r-- 1 pi pi  18649 Nov 23 02:05 eve1123020101_2_chart.png
# -rw-r--r-- 1 pi pi 301502 Nov 23 02:11 bds_v5.ipynb
# -rw-r--r-- 1 pi pi 160091 Nov 23 02:11 eve1123021144_raw_1.jpg
# -rw-r--r-- 1 pi pi 244367 Nov 23 02:12 eve1123021144_raw_2.jpg
# -rw------- 1 pi pi      0 Nov 23 02:12 capture_lockfile

# %%
# %matplotlib inline
import PIL
from glob import glob
import matplotlib.pyplot as plt
images = [ PIL.Image.open(f) for f in sorted(glob(raw_filename + '*')) ]

print("plotting %s images" % len(images))

for i in range(len(images)):
    print("printing trials %s at shutter speeds %d" % (images[i].filename, shutter_settings[i]))
    plt.figure()
    plt.imshow(images[i])
    
#print(images)
#for im in images:
#    #print(im.filename)
#    Image(filename=im.filename, retina=True)
# Out:
# plotting 2 images
# printing trials eve1123021144_raw_1.jpg at shutter speeds 1000000
# printing trials eve1123021144_raw_2.jpg at shutter speeds 2000000

# %%
for i in range(len(images)):
    print("Analyzing trials %s at shutter speeds %d" % (images[i].filename, shutter_settings[i]))
    # 2. Get picture's aperture
    im = PIL.Image.open(images[i].filename)
    print("locating aperture for %s" % images[i].filename)
    pic_pixels = im.load()
    aperture = find_aperture(pic_pixels, im.size[0], im.size[1])

# 3. Draw aperture and scan line
    spectrum_angle = -0.01
    draw = PIL.ImageDraw.Draw(im)
    draw_aperture(aperture, draw)
    draw_scan_line(aperture, draw, spectrum_angle)

# 4. Draw graph on picture
    print("analysing image for %s" % images[i].filename)
    wavelength_factor = 0.94
    #wavelength_factor = 0.892  # 1000/mm
    #wavelength_factor=0.892*2.0*600/650 # 500/mm
    results, max_result = draw_graph(draw, pic_pixels, aperture, spectrum_angle, wavelength_factor)

# 5. Inform user of issues with exposure
    inform_user_of_exposure(max_result)

# 6. Save picture with overlay
    save_image_with_overlay(im, name + "_" + str(i+1))

# 7. Normalize results for export
    print("exporting CSV for %s" % images[i].filename)
    normalized_results = normalize_results(results, max_result)

# 8. Save csv of results
    export_csv(name + "_" + str(i+1), normalized_results)

# 9. Generate spectrum diagram
    print("generating chart for %s" % images[i].filename)
    export_diagram(name + "_" + str(i+1), normalized_results)
# Out:
# Analyzing trials eve1123021144_raw_1.jpg at shutter speeds 1000000
# locating aperture for eve1123021144_raw_1.jpg
# spectrum_top is 262 spectrum bottom is 501
# analysing image for eve1123021144_raw_1.jpg
# ideal exposure between 0.15 and 0.30
# exposure= 0.7380485114128567
# consider reducing shutter time
# exporting CSV for eve1123021144_raw_1.jpg
# generating chart for eve1123021144_raw_1.jpg
# Analyzing trials eve1123021144_raw_2.jpg at shutter speeds 2000000
# locating aperture for eve1123021144_raw_2.jpg
# spectrum_top is 264 spectrum bottom is 495
# analysing image for eve1123021144_raw_2.jpg
# ideal exposure between 0.15 and 0.30
# exposure= 1.0366460660692884
# consider reducing shutter time
# exporting CSV for eve1123021144_raw_2.jpg
# generating chart for eve1123021144_raw_2.jpg

# %%
# !ls -ltr
# Out:
# total 6712
# drwxr-xr-x 2 pi pi   4096 Nov 22 23:13 save
# drwxr-xr-x 2 pi pi   4096 Nov 22 23:58 junk
# -rw-r--r-- 1 pi pi  27970 Nov 22 23:59 eve1122235853_raw_1.jpg
# -rw-r--r-- 1 pi pi  33735 Nov 22 23:59 eve1122235853_raw_2.jpg
# -rw-r--r-- 1 pi pi  40264 Nov 22 23:59 eve1122235853_raw_3.jpg
# -rw-r--r-- 1 pi pi  46333 Nov 22 23:59 eve1122235853_raw_4.jpg
# -rw-r--r-- 1 pi pi  51706 Nov 23 00:00 eve1122235853_raw_5.jpg
# -rw-r--r-- 1 pi pi   9756 Nov 23 00:00 eve1122235853_1_out.jpg
# -rw-r--r-- 1 pi pi     21 Nov 23 00:00 eve1122235853_1.csv
# -rw-r--r-- 1 pi pi   3314 Nov 23 00:00 eve1122235853_1_chart.png
# -rw-r--r-- 1 pi pi  10613 Nov 23 00:00 eve1122235853_2_out.jpg
# -rw-r--r-- 1 pi pi     21 Nov 23 00:00 eve1122235853_2.csv
# -rw-r--r-- 1 pi pi   3314 Nov 23 00:00 eve1122235853_2_chart.png
# -rw-r--r-- 1 pi pi  11481 Nov 23 00:00 eve1122235853_3_out.jpg
# -rw-r--r-- 1 pi pi     21 Nov 23 00:00 eve1122235853_3.csv
# -rw-r--r-- 1 pi pi   3314 Nov 23 00:00 eve1122235853_3_chart.png
# -rw-r--r-- 1 pi pi  12298 Nov 23 00:00 eve1122235853_4_out.jpg
# -rw-r--r-- 1 pi pi     21 Nov 23 00:00 eve1122235853_4.csv
# -rw-r--r-- 1 pi pi   3314 Nov 23 00:00 eve1122235853_4_chart.png
# -rw-r--r-- 1 pi pi  12976 Nov 23 00:00 eve1122235853_5_out.jpg
# -rw-r--r-- 1 pi pi     21 Nov 23 00:00 eve1122235853_5.csv
# -rw-r--r-- 1 pi pi   3314 Nov 23 00:00 eve1122235853_5_chart.png
# -rw-r--r-- 1 pi pi 173839 Nov 23 01:03 eve1123010343_raw_1.jpg
# -rw-r--r-- 1 pi pi 251728 Nov 23 01:04 eve1123010343_raw_2.jpg
# -rw-r--r-- 1 pi pi  47568 Nov 23 01:06 eve1123010343_1_out.jpg
# -rw-r--r-- 1 pi pi  11405 Nov 23 01:06 eve1123010343_1.csv
# -rw-r--r-- 1 pi pi  18878 Nov 23 01:06 eve1123010343_1_chart.png
# -rw-r--r-- 1 pi pi  58307 Nov 23 01:06 eve1123010343_2_out.jpg
# -rw-r--r-- 1 pi pi  11405 Nov 23 01:06 eve1123010343_2.csv
# -rw-r--r-- 1 pi pi  20130 Nov 23 01:06 eve1123010343_2_chart.png
# -rw-r--r-- 1 pi pi 166715 Nov 23 01:10 eve1123011034_raw_1.jpg
# -rw-r--r-- 1 pi pi 250699 Nov 23 01:11 eve1123011034_raw_2.jpg
# -rw-r--r-- 1 pi pi  42056 Nov 23 01:18 eve1123011034_1_out.jpg
# -rw-r--r-- 1 pi pi  11502 Nov 23 01:18 eve1123011034_1.csv
# -rw-r--r-- 1 pi pi  17413 Nov 23 01:18 eve1123011034_1_chart.png
# -rw-r--r-- 1 pi pi  55102 Nov 23 01:18 eve1123011034_2_out.jpg
# -rw-r--r-- 1 pi pi  11405 Nov 23 01:18 eve1123011034_2.csv
# -rw-r--r-- 1 pi pi  19422 Nov 23 01:18 eve1123011034_2_chart.png
# -rw-r--r-- 1 pi pi 171148 Nov 23 01:31 eve1123013100_raw_1.jpg
# -rw-r--r-- 1 pi pi 250794 Nov 23 01:31 eve1123013100_raw_2.jpg
# -rw-r--r-- 1 pi pi 167467 Nov 23 01:33 eve1123013320_raw_1.jpg
# -rw-r--r-- 1 pi pi 250483 Nov 23 01:33 eve1123013320_raw_2.jpg
# -rw-r--r-- 1 pi pi 169940 Nov 23 01:41 eve1123014116_raw_1.jpg
# -rw-r--r-- 1 pi pi 250180 Nov 23 01:41 eve1123014116_raw_2.jpg
# -rw-r--r-- 1 pi pi  41152 Nov 23 01:41 eve1123014116_1_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 01:41 eve1123014116_1.csv
# -rw-r--r-- 1 pi pi   6721 Nov 23 01:41 eve1123014116_1_chart.png
# -rw-r--r-- 1 pi pi  52890 Nov 23 01:41 eve1123014116_2_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 01:41 eve1123014116_2.csv
# -rw-r--r-- 1 pi pi   7833 Nov 23 01:41 eve1123014116_2_chart.png
# -rw-r--r-- 1 pi pi 160121 Nov 23 01:49 eve1123014855_raw_1.jpg
# -rw-r--r-- 1 pi pi 244920 Nov 23 01:49 eve1123014855_raw_2.jpg
# -rw-r--r-- 1 pi pi  39798 Nov 23 01:49 eve1123014855_1_out.jpg
# -rw-r--r-- 1 pi pi   9026 Nov 23 01:49 eve1123014855_1.csv
# -rw-r--r-- 1 pi pi   6587 Nov 23 01:49 eve1123014855_1_chart.png
# -rw-r--r-- 1 pi pi  51892 Nov 23 01:49 eve1123014855_2_out.jpg
# -rw-r--r-- 1 pi pi   9026 Nov 23 01:49 eve1123014855_2.csv
# -rw-r--r-- 1 pi pi   7621 Nov 23 01:49 eve1123014855_2_chart.png
# -rw-r--r-- 1 pi pi 164761 Nov 23 01:51 eve1123015135_raw_1.jpg
# -rw-r--r-- 1 pi pi 244970 Nov 23 01:52 eve1123015135_raw_2.jpg
# -rw-r--r-- 1 pi pi  40291 Nov 23 01:56 eve1123015135_1_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 01:56 eve1123015135_1.csv
# -rw-r--r-- 1 pi pi   6806 Nov 23 01:56 eve1123015135_1_chart.png
# -rw-r--r-- 1 pi pi  52217 Nov 23 01:56 eve1123015135_2_out.jpg
# -rw-r--r-- 1 pi pi   9026 Nov 23 01:56 eve1123015135_2.csv
# -rw-r--r-- 1 pi pi   7856 Nov 23 01:56 eve1123015135_2_chart.png
# -rw-r--r-- 1 pi pi 162817 Nov 23 01:57 eve1123015721_raw_1.jpg
# -rw-r--r-- 1 pi pi 244735 Nov 23 01:57 eve1123015721_raw_2.jpg
# -rw-r--r-- 1 pi pi  40738 Nov 23 01:58 eve1123015721_1_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 01:58 eve1123015721_1.csv
# -rw-r--r-- 1 pi pi   7049 Nov 23 01:58 eve1123015721_1_chart.png
# -rw-r--r-- 1 pi pi  52699 Nov 23 01:58 eve1123015721_2_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 01:58 eve1123015721_2.csv
# -rw-r--r-- 1 pi pi   8028 Nov 23 01:58 eve1123015721_2_chart.png
# -rw-r--r-- 1 pi pi 167221 Nov 23 01:59 eve1123015940_raw_1.jpg
# -rw-r--r-- 1 pi pi 244784 Nov 23 02:00 eve1123015940_raw_2.jpg
# -rw-r--r-- 1 pi pi  41305 Nov 23 02:00 eve1123015940_1_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 02:00 eve1123015940_1.csv
# -rw-r--r-- 1 pi pi   7058 Nov 23 02:00 eve1123015940_1_chart.png
# -rw-r--r-- 1 pi pi  52883 Nov 23 02:00 eve1123015940_2_out.jpg
# -rw-r--r-- 1 pi pi   9015 Nov 23 02:00 eve1123015940_2.csv
# -rw-r--r-- 1 pi pi   7958 Nov 23 02:00 eve1123015940_2_chart.png
# -rw-r--r-- 1 pi pi 160134 Nov 23 02:01 eve1123020101_raw_1.jpg
# -rw-r--r-- 1 pi pi 294114 Nov 23 02:01 bds_vBAD.ipynb
# -rw-r--r-- 1 pi pi 245326 Nov 23 02:01 eve1123020101_raw_2.jpg
# -rw-r--r-- 1 pi pi  37409 Nov 23 02:05 eve1123020101_1_out.jpg
# -rw-r--r-- 1 pi pi  11405 Nov 23 02:05 eve1123020101_1.csv
# -rw-r--r-- 1 pi pi  16967 Nov 23 02:05 eve1123020101_1_chart.png
# -rw-r--r-- 1 pi pi  49478 Nov 23 02:05 eve1123020101_2_out.jpg
# -rw-r--r-- 1 pi pi  11405 Nov 23 02:05 eve1123020101_2.csv
# -rw-r--r-- 1 pi pi  18649 Nov 23 02:05 eve1123020101_2_chart.png
# -rw-r--r-- 1 pi pi 301502 Nov 23 02:11 bds_v5.ipynb
# -rw-r--r-- 1 pi pi 160091 Nov 23 02:11 eve1123021144_raw_1.jpg
# -rw-r--r-- 1 pi pi 244367 Nov 23 02:12 eve1123021144_raw_2.jpg
# -rw------- 1 pi pi      0 Nov 23 02:12 capture_lockfile
# -rw-r--r-- 1 pi pi  43404 Nov 23 02:12 eve1123021144_1_out.jpg
# -rw-r--r-- 1 pi pi  11405 Nov 23 02:12 eve1123021144_1.csv
# -rw-r--r-- 1 pi pi  17590 Nov 23 02:12 eve1123021144_1_chart.png
# -rw-r--r-- 1 pi pi  55141 Nov 23 02:12 eve1123021144_2_out.jpg
# -rw-r--r-- 1 pi pi  11502 Nov 23 02:12 eve1123021144_2.csv
# -rw-r--r-- 1 pi pi  19802 Nov 23 02:12 eve1123021144_2_chart.png

# %%
print(name)
processed_images = [ PIL.Image.open(f) for f in sorted(glob(name + '*_out.jpg')) ]
processed_charts = [ PIL.Image.open(f) for f in sorted(glob(name + '*_chart.png')) ]

print("plotting %s images" % len(processed_images))

for i in range(len(processed_images)):
    print("printing trials %s at shutter speeds %d" % (processed_images[i].filename, shutter_settings[i]))
    plt.figure()
    plt.imshow(processed_images[i])

print("plotting %s charts" % len(processed_charts))
    
for i in range(len(processed_charts)):
    print("printing trials %s at shutter speeds %d" % (processed_charts[i].filename, shutter_settings[i]))
    plt.figure()
    plt.imshow(processed_charts[i])
# Out:
# eve1123021144
# plotting 2 images
# printing trials eve1123021144_1_out.jpg at shutter speeds 1000000
# printing trials eve1123021144_2_out.jpg at shutter speeds 2000000
# plotting 2 charts
# printing trials eve1123021144_1_chart.png at shutter speeds 1000000
# printing trials eve1123021144_2_chart.png at shutter speeds 2000000
